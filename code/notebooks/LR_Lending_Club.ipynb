# %% [markdown]
# ## Dependencias

# %%
import numpy as np 
import pandas as pd 
from sklearn.tree import DecisionTreeClassifier,plot_tree
from sklearn.metrics import accuracy_score,roc_auc_score,classification_report
from sklearn.model_selection import RandomizedSearchCV,train_test_split
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder
from sklearn.feature_selection import SelectKBest
from functools import reduce 
from varclushi import VarClusHi
from CreditScoringToolkit import frequency_table,DiscreteNormalizer
pd.set_option('display.max_columns',None)

# %% [markdown]
# ## Lectura de datos

# %%
data = pd.read_csv('../data/acc.csv',dtype=str)
data.shape
# Out:
# (2260701, 151)

# %%
# Rename variables according to provided mapping
rename_dict = {
    'loan_amnt': 'c_loan_amnt',
    'grade': 'd_grade',
    'sub_grade': 'd_sub_grade',
    'emp_length': 'd_emp_length',
    'home_ownership': 'd_home_ownership',
    'annual_inc': 'c_annual_inc',
    'purpose': 'd_purpose',
    'addr_state': 'd_addr_state',
    'dti': 'c_dti',
    'delinq_2yrs': 'c_delinq_2yrs',
    'fico_range_low': 'c_fico_range_low',
    'fico_range_high': 'c_fico_range_high',
    'inq_last_6mths': 'c_inq_last_6mths',
    'mths_since_last_delinq': 'c_mths_since_last_delinq',
    'mths_since_last_record': 'c_mths_since_last_record',
    'open_acc': 'c_open_acc',
    'pub_rec': 'c_pub_rec',
    'revol_bal': 'c_revol_bal',
    'revol_util': 'c_revol_util',
    'total_acc': 'c_total_acc',
    'application_type': 'd_application_type',
    'acc_now_delinq': 'c_acc_now_delinq',
    'tot_coll_amt': 'c_tot_coll_amt',
    'tot_cur_bal': 'c_tot_cur_bal',
    'open_acc_6m': 'c_open_acc_6m',
    'open_act_il': 'c_open_act_il',
    'open_il_12m': 'c_open_il_12m',
    'open_il_24m': 'c_open_il_24m',
    'mths_since_rcnt_il': 'c_mths_since_rcnt_il',
    'total_bal_il': 'c_total_bal_il',
    'il_util': 'c_il_util',
    'open_rv_12m': 'c_open_rv_12m',
    'open_rv_24m': 'c_open_rv_24m',
    'max_bal_bc': 'c_max_bal_bc',
    'all_util': 'c_all_util',
    'total_rev_hi_lim': 'c_total_rev_hi_lim',
    'inq_fi': 'c_inq_fi',
    'total_cu_tl': 'c_total_cu_tl',
    'inq_last_12m': 'c_inq_last_12m',
    'acc_open_past_24mths': 'c_acc_open_past_24mths',
    'avg_cur_bal': 'c_avg_cur_bal',
    'bc_open_to_buy': 'c_bc_open_to_buy',
    'bc_util': 'c_bc_util',
    'chargeoff_within_12_mths': 'c_chargeoff_within_12_mths',
    'delinq_amnt': 'c_delinq_amnt',
    'mo_sin_old_il_acct': 'c_mo_sin_old_il_acct',
    'mo_sin_old_rev_tl_op': 'c_mo_sin_old_rev_tl_op',
    'mo_sin_rcnt_rev_tl_op': 'c_mo_sin_rcnt_rev_tl_op',
    'mo_sin_rcnt_tl': 'c_mo_sin_rcnt_tl',
    'mort_acc': 'c_mort_acc',
    'mths_since_recent_bc': 'c_mths_since_recent_bc',
    'mths_since_recent_bc_dlq': 'c_mths_since_recent_bc_dlq',
    'mths_since_recent_inq': 'c_mths_since_recent_inq',
    'mths_since_recent_revol_delinq': 'c_mths_since_recent_revol_delinq',
    'num_accts_ever_120_pd': 'c_num_accts_ever_120_pd',
    'num_actv_bc_tl': 'c_num_actv_bc_tl',
    'num_actv_rev_tl': 'c_num_actv_rev_tl',
    'num_bc_sats': 'c_num_bc_sats',
    'num_bc_tl': 'c_num_bc_tl',
    'num_il_tl': 'c_num_il_tl',
    'num_op_rev_tl': 'c_num_op_rev_tl',
    'num_rev_accts': 'c_num_rev_accts',
    'num_rev_tl_bal_gt_0': 'c_num_rev_tl_bal_gt_0',
    'num_sats': 'c_num_sats',
    'num_tl_120dpd_2m': 'c_num_tl_120dpd_2m',
    'num_tl_30dpd': 'c_num_tl_30dpd',
    'num_tl_90g_dpd_24m': 'c_num_tl_90g_dpd_24m',
    'num_tl_op_past_12m': 'c_num_tl_op_past_12m',
    'pct_tl_nvr_dlq': 'c_pct_tl_nvr_dlq',
    'percent_bc_gt_75': 'c_percent_bc_gt_75',
    'pub_rec_bankruptcies': 'c_pub_rec_bankruptcies',
    'tax_liens': 'c_tax_liens',
    'tot_hi_cred_lim': 'c_tot_hi_cred_lim',
    'total_bal_ex_mort': 'c_total_bal_ex_mort',
    'total_bc_limit': 'c_total_bc_limit',
    'total_il_high_credit_limit': 'c_total_il_high_credit_limit',
    'disbursement_method': 'd_disbursement_method',
}

data.rename(columns=rename_dict, inplace=True)

# %%
data['loan_status'].value_counts()
# Out:
# loan_status
# Fully Paid                                             1076751
# Current                                                 878317
# Charged Off                                             268559
# Late (31-120 days)                                       21467
# In Grace Period                                           8436
# Late (16-30 days)                                         4349
# Does not meet the credit policy. Status:Fully Paid        1988
# Does not meet the credit policy. Status:Charged Off        761
# Default                                                     40
# Name: count, dtype: int64

# %%
data = data.loc[data['loan_status'].isin(['Fully Paid','Current','Charged Off','Late (31-120 days)'])].reset_index(drop=True)
data['target'] = 1-data['loan_status'].isin(['Fully Paid','Current'])

# %%
data.sample(2)
# Out:
#               id member_id c_loan_amnt funded_amnt funded_amnt_inv  \
# 404145  38639931       NaN     20000.0     20000.0         20000.0
# 343727  42333549       NaN     19350.0     19350.0         19100.0
#
#               term int_rate installment d_grade d_sub_grade  \
# 404145   36 months    11.44      658.95       B          B4
# 343727   60 months    22.99      545.38       F          F1
#
#                   emp_title d_emp_length d_home_ownership c_annual_inc  \
# 404145  Executive Assistant    10+ years         MORTGAGE      70000.0
# 343727    assistant manager    10+ years             RENT      54000.0
#
#        verification_status   issue_d loan_status pymnt_plan  \
# 404145     Source Verified  Jan-2015  Fully Paid          n
# 343727            Verified  Mar-2015  Fully Paid          n
#
#                                                       url desc  \
# 404145  https://lendingclub.com/browse/loanDetail.acti...  NaN
# 343727  https://lendingclub.com/browse/loanDetail.acti...  NaN
#
#                  d_purpose               title zip_code d_addr_state  c_dti  \
# 404145  debt_consolidation  Debt consolidation    801xx           CO   19.0
# 343727  debt_consolidation  Debt consolidation    120xx           NY  32.99
#
#        c_delinq_2yrs earliest_cr_line c_fico_range_low c_fico_range_high  \
# 404145           1.0         Mar-2003            660.0             664.0
# 343727           0.0         Apr-1994            720.0             724.0
#
#        c_inq_last_6mths c_mths_since_last_delinq c_mths_since_last_record  \
# 404145              1.0                     11.0                      NaN
# 343727              3.0                      NaN                      NaN
#
#        c_open_acc c_pub_rec c_revol_bal c_revol_util c_total_acc  \
# 404145       17.0       0.0     13263.0         51.6        30.0
# 343727       28.0       0.0     15603.0         31.8        45.0
#
#        initial_list_status out_prncp out_prncp_inv     total_pymnt  \
# 404145                   w       0.0           0.0  23696.76132721
# 343727                   f       0.0           0.0        19443.29
#
#        total_pymnt_inv total_rec_prncp total_rec_int total_rec_late_fee  \
# 404145        23696.76         20000.0       3696.76                0.0
# 343727        19192.08         19350.0         93.29                0.0
#
#        recoveries collection_recovery_fee last_pymnt_d last_pymnt_amnt  \
# 404145        0.0                     0.0     Jan-2018          658.93
# 343727        0.0                     0.0     Apr-2015        19492.72
#
#        next_pymnt_d last_credit_pull_d last_fico_range_high  \
# 404145          NaN           Mar-2019                739.0
# 343727          NaN           Mar-2019                694.0
#
#        last_fico_range_low collections_12_mths_ex_med  \
# 404145               735.0                        0.0
# 343727               690.0                        0.0
#
#        mths_since_last_major_derog policy_code d_application_type  \
# 404145                         NaN         1.0         Individual
# 343727                         NaN         1.0         Individual
#
#        annual_inc_joint dti_joint verification_status_joint c_acc_now_delinq  \
# 404145              NaN       NaN                       NaN              0.0
# 343727              NaN       NaN                       NaN              0.0
#
#        c_tot_coll_amt c_tot_cur_bal c_open_acc_6m c_open_act_il c_open_il_12m  \
# 404145          308.0      189831.0           NaN           NaN           NaN
# 343727            0.0       50774.0           NaN           NaN           NaN
#
#        c_open_il_24m c_mths_since_rcnt_il c_total_bal_il c_il_util  \
# 404145           NaN                  NaN            NaN       NaN
# 343727           NaN                  NaN            NaN       NaN
#
#        c_open_rv_12m c_open_rv_24m c_max_bal_bc c_all_util c_total_rev_hi_lim  \
# 404145           NaN           NaN          NaN        NaN            25700.0
# 343727           NaN           NaN          NaN        NaN            49100.0
#
#        c_inq_fi c_total_cu_tl c_inq_last_12m c_acc_open_past_24mths  \
# 404145      NaN           NaN            NaN                    2.0
# 343727      NaN           NaN            NaN                   15.0
#
#        c_avg_cur_bal c_bc_open_to_buy c_bc_util c_chargeoff_within_12_mths  \
# 404145       11864.0           1436.0      81.8                        0.0
# 343727        1953.0          23011.0      40.1                        0.0
#
#        c_delinq_amnt c_mo_sin_old_il_acct c_mo_sin_old_rev_tl_op  \
# 404145           0.0                141.0                  142.0
# 343727           0.0                133.0                  251.0
#
#        c_mo_sin_rcnt_rev_tl_op c_mo_sin_rcnt_tl c_mort_acc  \
# 404145                    15.0             14.0        4.0
# 343727                     2.0              2.0        0.0
#
#        c_mths_since_recent_bc c_mths_since_recent_bc_dlq  \
# 404145                   72.0                        NaN
# 343727                    2.0                        NaN
#
#        c_mths_since_recent_inq c_mths_since_recent_revol_delinq  \
# 404145                     5.0                             11.0
# 343727                     0.0                              NaN
#
#        c_num_accts_ever_120_pd c_num_actv_bc_tl c_num_actv_rev_tl  \
# 404145                     0.0              2.0               6.0
# 343727                     1.0              5.0               6.0
#
#        c_num_bc_sats c_num_bc_tl c_num_il_tl c_num_op_rev_tl c_num_rev_accts  \
# 404145           3.0         9.0         3.0            13.0            23.0
# 343727          12.0        16.0        14.0            24.0            30.0
#
#        c_num_rev_tl_bal_gt_0 c_num_sats c_num_tl_120dpd_2m c_num_tl_30dpd  \
# 404145                   6.0       17.0                0.0            0.0
# 343727                   6.0       28.0                0.0            0.0
#
#        c_num_tl_90g_dpd_24m c_num_tl_op_past_12m c_pct_tl_nvr_dlq  \
# 404145                  0.0                  0.0             96.7
# 343727                  0.0                 10.0             97.7
#
#        c_percent_bc_gt_75 c_pub_rec_bankruptcies c_tax_liens  \
# 404145               66.7                    0.0         0.0
# 343727               16.7                    0.0         0.0
#
#        c_tot_hi_cred_lim c_total_bal_ex_mort c_total_bc_limit  \
# 404145          226215.0             34283.0           7900.0
# 343727           98842.0             50774.0          38400.0
#
#        c_total_il_high_credit_limit revol_bal_joint sec_app_fico_range_low  \
# 404145                      31291.0             NaN                    NaN
# 343727                      40622.0             NaN                    NaN
#
#        sec_app_fico_range_high sec_app_earliest_cr_line  \
# 404145                     NaN                      NaN
# 343727                     NaN                      NaN
#
#        sec_app_inq_last_6mths sec_app_mort_acc sec_app_open_acc  \
# 404145                    NaN              NaN              NaN
# 343727                    NaN              NaN              NaN
#
#        sec_app_revol_util sec_app_open_act_il sec_app_num_rev_accts  \
# 404145                NaN                 NaN                   NaN
# 343727                NaN                 NaN                   NaN
#
#        sec_app_chargeoff_within_12_mths sec_app_collections_12_mths_ex_med  \
# 404145                              NaN                                NaN
# 343727                              NaN                                NaN
#
#        sec_app_mths_since_last_major_derog hardship_flag hardship_type  \
# 404145                                 NaN             N           NaN
# 343727                                 NaN             N           NaN
#
#        hardship_reason hardship_status deferral_term hardship_amount  \
# 404145             NaN             NaN           NaN             NaN
# 343727             NaN             NaN           NaN             NaN
#
#        hardship_start_date hardship_end_date payment_plan_start_date  \
# 404145                 NaN               NaN                     NaN
# 343727                 NaN               NaN                     NaN
#
#        hardship_length hardship_dpd hardship_loan_status  \
# 404145             NaN          NaN                  NaN
# 343727             NaN          NaN                  NaN
#
#        orig_projected_additional_accrued_interest  \
# 404145                                        NaN
# 343727                                        NaN
#
#        hardship_payoff_balance_amount hardship_last_payment_amount  \
# 404145                            NaN                          NaN
# 343727                            NaN                          NaN
#
#        d_disbursement_method debt_settlement_flag debt_settlement_flag_date  \
# 404145                  Cash                    N                       NaN
# 343727                  Cash                    N                       NaN
#
#        settlement_status settlement_date settlement_amount  \
# 404145               NaN             NaN               NaN
# 343727               NaN             NaN               NaN
#
#        settlement_percentage settlement_term  target
# 404145                   NaN             NaN       0
# 343727                   NaN             NaN       0

# %% [markdown]
# ## Clasificación de variables

# %%
um = ['id']
varc = [v for v in data.columns if v[:2]=='c_']
vard = [v for v in data.columns if v[:2]=='d_']
vart = ['target']
len(varc),len(vard)
# Out:
# (69, 8)

# %% [markdown]
# ## Partición

# %%
data = data[um+vart+varc+vard]

# %%
data.head()
# Out:
#          id  target c_loan_amnt c_annual_inc  c_dti c_delinq_2yrs  \
# 0  68407277       0      3600.0      55000.0   5.91           0.0
# 1  68355089       0     24700.0      65000.0  16.06           1.0
# 2  68341763       0     20000.0      63000.0  10.78           0.0
# 3  66310712       0     35000.0     110000.0  17.06           0.0
# 4  68476807       0     10400.0     104433.0  25.37           1.0
#
#   c_fico_range_low c_fico_range_high c_inq_last_6mths  \
# 0            675.0             679.0              1.0
# 1            715.0             719.0              4.0
# 2            695.0             699.0              0.0
# 3            785.0             789.0              0.0
# 4            695.0             699.0              3.0
#
#   c_mths_since_last_delinq c_mths_since_last_record c_open_acc c_pub_rec  \
# 0                     30.0                      NaN        7.0       0.0
# 1                      6.0                      NaN       22.0       0.0
# 2                      NaN                      NaN        6.0       0.0
# 3                      NaN                      NaN       13.0       0.0
# 4                     12.0                      NaN       12.0       0.0
#
#   c_revol_bal c_revol_util c_total_acc c_acc_now_delinq c_tot_coll_amt  \
# 0      2765.0         29.7        13.0              0.0          722.0
# 1     21470.0         19.2        38.0              0.0            0.0
# 2      7869.0         56.2        18.0              0.0            0.0
# 3      7802.0         11.6        17.0              0.0            0.0
# 4     21929.0         64.5        35.0              0.0            0.0
#
#   c_tot_cur_bal c_open_acc_6m c_open_act_il c_open_il_12m c_open_il_24m  \
# 0      144904.0           2.0           2.0           0.0           1.0
# 1      204396.0           1.0           1.0           0.0           1.0
# 2      189699.0           0.0           1.0           0.0           4.0
# 3      301500.0           1.0           1.0           0.0           1.0
# 4      331730.0           1.0           3.0           0.0           3.0
#
#   c_mths_since_rcnt_il c_total_bal_il c_il_util c_open_rv_12m c_open_rv_24m  \
# 0                 21.0         4981.0      36.0           3.0           3.0
# 1                 19.0        18005.0      73.0           2.0           3.0
# 2                 19.0        10827.0      73.0           0.0           2.0
# 3                 23.0        12609.0      70.0           1.0           1.0
# 4                 14.0        73839.0      84.0           4.0           7.0
#
#   c_max_bal_bc c_all_util c_total_rev_hi_lim c_inq_fi c_total_cu_tl  \
# 0        722.0       34.0             9300.0      3.0           1.0
# 1       6472.0       29.0           111800.0      0.0           0.0
# 2       2081.0       65.0            14000.0      2.0           5.0
# 3       6987.0       45.0            67300.0      0.0           1.0
# 4       9702.0       78.0            34000.0      2.0           1.0
#
#   c_inq_last_12m c_acc_open_past_24mths c_avg_cur_bal c_bc_open_to_buy  \
# 0            4.0                    4.0       20701.0           1506.0
# 1            6.0                    4.0        9733.0          57830.0
# 2            1.0                    6.0       31617.0           2737.0
# 3            0.0                    2.0       23192.0          54962.0
# 4            3.0                   10.0       27644.0           4567.0
#
#   c_bc_util c_chargeoff_within_12_mths c_delinq_amnt c_mo_sin_old_il_acct  \
# 0      37.2                        0.0           0.0                148.0
# 1      27.1                        0.0           0.0                113.0
# 2      55.9                        0.0           0.0                125.0
# 3      12.1                        0.0           0.0                 36.0
# 4      77.5                        0.0           0.0                128.0
#
#   c_mo_sin_old_rev_tl_op c_mo_sin_rcnt_rev_tl_op c_mo_sin_rcnt_tl c_mort_acc  \
# 0                  128.0                     3.0              3.0        1.0
# 1                  192.0                     2.0              2.0        4.0
# 2                  184.0                    14.0             14.0        5.0
# 3                   87.0                     2.0              2.0        1.0
# 4                  210.0                     4.0              4.0        6.0
#
#   c_mths_since_recent_bc c_mths_since_recent_bc_dlq c_mths_since_recent_inq  \
# 0                    4.0                       69.0                     4.0
# 1                    2.0                        NaN                     0.0
# 2                  101.0                        NaN                    10.0
# 3                    2.0                        NaN                     NaN
# 4                    4.0                       12.0                     1.0
#
#   c_mths_since_recent_revol_delinq c_num_accts_ever_120_pd c_num_actv_bc_tl  \
# 0                             69.0                     2.0              2.0
# 1                              6.0                     0.0              5.0
# 2                              NaN                     0.0              2.0
# 3                              NaN                     0.0              4.0
# 4                             12.0                     0.0              4.0
#
#   c_num_actv_rev_tl c_num_bc_sats c_num_bc_tl c_num_il_tl c_num_op_rev_tl  \
# 0               4.0           2.0         5.0         3.0             4.0
# 1               5.0          13.0        17.0         6.0            20.0
# 2               3.0           2.0         4.0         6.0             4.0
# 3               5.0           8.0        10.0         2.0            10.0
# 4               6.0           5.0         9.0        10.0             7.0
#
#   c_num_rev_accts c_num_rev_tl_bal_gt_0 c_num_sats c_num_tl_120dpd_2m  \
# 0             9.0                   4.0        7.0                0.0
# 1            27.0                   5.0       22.0                0.0
# 2             7.0                   3.0        6.0                0.0
# 3            13.0                   5.0       13.0                0.0
# 4            19.0                   6.0       12.0                0.0
#
#   c_num_tl_30dpd c_num_tl_90g_dpd_24m c_num_tl_op_past_12m c_pct_tl_nvr_dlq  \
# 0            0.0                  0.0                  3.0             76.9
# 1            0.0                  0.0                  2.0             97.4
# 2            0.0                  0.0                  0.0            100.0
# 3            0.0                  0.0                  1.0            100.0
# 4            0.0                  0.0                  4.0             96.6
#
#   c_percent_bc_gt_75 c_pub_rec_bankruptcies c_tax_liens c_tot_hi_cred_lim  \
# 0                0.0                    0.0         0.0          178050.0
# 1                7.7                    0.0         0.0          314017.0
# 2               50.0                    0.0         0.0          218418.0
# 3                0.0                    0.0         0.0          381215.0
# 4               60.0                    0.0         0.0          439570.0
#
#   c_total_bal_ex_mort c_total_bc_limit c_total_il_high_credit_limit d_grade  \
# 0              7746.0           2400.0                      13734.0       C
# 1             39475.0          79300.0                      24667.0       C
# 2             18696.0           6200.0                      14877.0       B
# 3             52226.0          62500.0                      18000.0       C
# 4             95768.0          20300.0                      88097.0       F
#
#   d_sub_grade d_emp_length d_home_ownership           d_purpose d_addr_state  \
# 0          C4    10+ years         MORTGAGE  debt_consolidation           PA
# 1          C1    10+ years         MORTGAGE      small_business           SD
# 2          B4    10+ years         MORTGAGE    home_improvement           IL
# 3          C5    10+ years         MORTGAGE  debt_consolidation           NJ
# 4          F1      3 years         MORTGAGE      major_purchase           PA
#
#   d_application_type d_disbursement_method
# 0         Individual                  Cash
# 1         Individual                  Cash
# 2          Joint App                  Cash
# 3         Individual                  Cash
# 4         Individual                  Cash

# %%
for v in vard:
    data[v] = data[v].fillna('MISSING')
for v in varc:
    data[v] = pd.to_numeric(data[v],errors='coerce')

# %%
train,valid = train_test_split(data,test_size=0.3)
train.reset_index(drop=True,inplace=True)
valid.reset_index(drop=True,inplace=True)
train.shape,valid.shape
# Out:
# ((1571565, 79), (673529, 79))

# %% [markdown]
# ## Análisis Exploratorio de Datos

# %% [markdown]
# ### Ausentes

# %%
miss = ((train[varc].isna().sum())/len(train)).sort_values(ascending=False)
fuera = list(miss[miss>0.3].index)
print(len(fuera))
varc = [v for v in varc if v not in fuera]
train.drop(fuera,axis=1,inplace=True)
# Out:
# 18

# %% [markdown]
# ### Multicolinealidad

# %%
im = SimpleImputer(strategy='median')
Xi = pd.DataFrame(im.fit_transform(train[varc]),columns=varc)

# %%
vc = VarClusHi(df=Xi.sample(frac=0.01),feat_list=varc).varclus().rsquare

# %%
mc = list(vc.sort_values(by=['Cluster','RS_Ratio']).groupby('Cluster').first()['Variable'])

# %%
im = SimpleImputer(strategy='median')
im.fit(train[mc])
# Out:
# SimpleImputer(strategy='median')

# %% [markdown]
# ### Normalización de variables discretas

# %%
frequency_table(train,vard)
# Out:
# **** Frequency Table for d_grade ****
#
#          Abs. Freq.  Rel. Freq.  Cum. Abs. Freq.  Cum. Rel. Freq.
# d_grade
# A            302166    0.192271           302166         0.192271
# B            462400    0.294229           764566         0.486500
# C            451840    0.287510          1216406         0.774009
# D            224280    0.142711          1440686         0.916721
# E             93770    0.059667          1534456         0.976387
# F             28808    0.018331          1563264         0.994718
# G              8301    0.005282          1571565         1.000000
#
#
#
#
# **** Frequency Table for d_sub_grade ****
#
#              Abs. Freq.  Rel. Freq.  Cum. Abs. Freq.  Cum. Rel. Freq.
# d_sub_grade
# A1                60832    0.038708            60832         0.038708
# A2                48645    0.030953           109477         0.069661
# A3                51117    0.032526           160594         0.102187
# A4                66605    0.042381           227199         0.144569
# A5                74967    0.047702           302166         0.192271
# B1                87316    0.055560           389482         0.247831
# B2                88060    0.056033           477542         0.303864
# B3                91755    0.058384           569297         0.362248
# B4                97584    0.062094           666881         0.424342
# B5                97685    0.062158           764566         0.486500
# C1               101679    0.064699           866245         0.551199
# C2                91296    0.058092           957541         0.609291
# C3                89544    0.056978          1047085         0.666269
# C4                88466    0.056292          1135551         0.722561
# C5                80855    0.051449          1216406         0.774009
# D1                56467    0.035930          1272873         0.809940
# D2                50442    0.032097          1323315         0.842036
# D3                44848    0.028537          1368163         0.870574
# D4                39306    0.025011          1407469         0.895584
# D5                33217    0.021136          1440686         0.916721
# E1                23303    0.014828          1463989         0.931548
# E2                20605    0.013111          1484594         0.944660
# E3                18495    0.011769          1503089         0.956428
# E4                15718    0.010001          1518807         0.966430
# E5                15649    0.009958          1534456         0.976387
# F1                 9334    0.005939          1543790         0.982327
# F2                 6411    0.004079          1550201         0.986406
# F3                 5347    0.003402          1555548         0.989808
# F4                 4206    0.002676          1559754         0.992485
# F5                 3510    0.002233          1563264         0.994718
# G1                 2839    0.001806          1566103         0.996524
# G2                 1856    0.001181          1567959         0.997705
# G3                 1426    0.000907          1569385         0.998613
# G4                 1151    0.000732          1570536         0.999345
# G5                 1029    0.000655          1571565         1.000000
#
#
#
#
# **** Frequency Table for d_emp_length ****
#
#               Abs. Freq.  Rel. Freq.  Cum. Abs. Freq.  Cum. Rel. Freq.
# d_emp_length
# 1 year            102824    0.065428           102824         0.065428
# 10+ years         520397    0.331133           623221         0.396561
# 2 years           141441    0.090000           764662         0.486561
# 3 years           125544    0.079885           890206         0.566446
# 4 years            94801    0.060323           985007         0.626768
# 5 years            97025    0.061738          1082032         0.688506
# 6 years            71268    0.045348          1153300         0.733854
# 7 years            64601    0.041106          1217901         0.774961
# 8 years            63941    0.040686          1281842         0.815647
# 9 years            55333    0.035209          1337175         0.850856
# < 1 year          132057    0.084029          1469232         0.934885
# MISSING           102333    0.065115          1571565         1.000000
#
#
#
#
# **** Frequency Table for d_home_ownership ****
#
#                   Abs. Freq.  Rel. Freq.  Cum. Abs. Freq.  Cum. Rel. Freq.
# d_home_ownership
# ANY                      697    0.000444              697         0.000444
# MORTGAGE              773088    0.491922           773785         0.492366
# NONE                      36    0.000023           773821         0.492389
# OTHER                    106    0.000067           773927         0.492456
# OWN                   175927    0.111944           949854         0.604400
# RENT                  621711    0.395600          1571565         1.000000
#
#
#
#
# **** Frequency Table for d_purpose ****
#
#                     Abs. Freq.  Rel. Freq.  Cum. Abs. Freq.  Cum. Rel. Freq.
# d_purpose
# car                      16652    0.010596            16652         0.010596
# credit_card             360020    0.229084           376672         0.239680
# debt_consolidation      888615    0.565433          1265287         0.805113
# educational                224    0.000143          1265511         0.805255
# home_improvement        104371    0.066412          1369882         0.871667
# house                     9712    0.006180          1379594         0.877847
# major_purchase           35006    0.022275          1414600         0.900122
# medical                  18964    0.012067          1433564         0.912189
# moving                   10637    0.006768          1444201         0.918957
# other                    96820    0.061607          1541021         0.980565
# renewable_energy           995    0.000633          1542016         0.981198
# small_business           17092    0.010876          1559108         0.992074
# vacation                 10842    0.006899          1569950         0.998972
# wedding                   1615    0.001028          1571565         1.000000
#
#
#
#
# **** Frequency Table for d_addr_state ****
#
#               Abs. Freq.  Rel. Freq.  Cum. Abs. Freq.  Cum. Rel. Freq.
# d_addr_state
# AK                  3643    0.002318             3643         0.002318
# AL                 18973    0.012073            22616         0.014391
# AR                 11815    0.007518            34431         0.021909
# AZ                 37496    0.023859            71927         0.045768
# CA                218805    0.139227           290732         0.184995
# CO                 33540    0.021342           324272         0.206337
# CT                 24753    0.015751           349025         0.222088
# DC                  3733    0.002375           352758         0.224463
# DE                  4478    0.002849           357236         0.227312
# FL                112389    0.071514           469625         0.298826
# GA                 51451    0.032739           521076         0.331565
# HI                  7434    0.004730           528510         0.336295
# IA                     4    0.000003           528514         0.336298
# ID                  3063    0.001949           531577         0.338247
# IL                 63436    0.040365           595013         0.378612
# IN                 26166    0.016650           621179         0.395261
# KS                 13165    0.008377           634344         0.403638
# KY                 15176    0.009657           649520         0.413295
# LA                 17810    0.011333           667330         0.424628
# MA                 35972    0.022889           703302         0.447517
# MD                 37603    0.023927           740905         0.471444
# ME                  3442    0.002190           744347         0.473634
# MI                 40757    0.025934           785104         0.499568
# MN                 27650    0.017594           812754         0.517162
# MO                 25004    0.015910           837758         0.533072
# MS                  8772    0.005582           846530         0.538654
# MT                  4363    0.002776           850893         0.541430
# NC                 43693    0.027802           894586         0.569233
# ND                  2556    0.001626           897142         0.570859
# NE                  5531    0.003519           902673         0.574378
# NH                  7767    0.004942           910440         0.579321
# NJ                 57894    0.036838           968334         0.616159
# NM                  8434    0.005367           976768         0.621526
# NV                 22816    0.014518           999584         0.636044
# NY                129481    0.082390          1129065         0.718434
# OH                 52169    0.033196          1181234         0.751629
# OK                 14344    0.009127          1195578         0.760756
# OR                 18611    0.011842          1214189         0.772599
# PA                 53490    0.034036          1267679         0.806635
# RI                  6983    0.004443          1274662         0.811078
# SC                 19472    0.012390          1294134         0.823468
# SD                  3157    0.002009          1297291         0.825477
# TN                 24602    0.015654          1321893         0.841132
# TX                129512    0.082410          1451405         0.923541
# UT                 10388    0.006610          1461793         0.930151
# VA                 43762    0.027846          1505555         0.957997
# VT                  3424    0.002179          1508979         0.960176
# WA                 32584    0.020733          1541563         0.980909
# WI                 20901    0.013299          1562464         0.994209
# WV                  5771    0.003672          1568235         0.997881
# WY                  3330    0.002119          1571565         1.000000
#
#
#
#
# **** Frequency Table for d_application_type ****
#
#                     Abs. Freq.  Rel. Freq.  Cum. Abs. Freq.  Cum. Rel. Freq.
# d_application_type
# Individual             1488090    0.946884          1488090         0.946884
# Joint App                83475    0.053116          1571565         1.000000
#
#
#
#
# **** Frequency Table for d_disbursement_method ****
#
#                        Abs. Freq.  Rel. Freq.  Cum. Abs. Freq.  \
# d_disbursement_method
# Cash                      1517078    0.965329          1517078
# DirectPay                   54487    0.034671          1571565
#
#                        Cum. Rel. Freq.
# d_disbursement_method
# Cash                          0.965329
# DirectPay                     1.000000

# %%
dn = DiscreteNormalizer(normalization_threshold=0.1)
dn.fit(train[vard])

# %%
varn = [f'n_{v}' for v in vard]
train[varn] = dn.transform(train[vard])

# %%
frequency_table(train,varn)
# Out:
# **** Frequency Table for n_d_grade ****
#
#            Abs. Freq.  Rel. Freq.  Cum. Abs. Freq.  Cum. Rel. Freq.
# n_d_grade
# A              302166    0.192271           302166         0.192271
# B              593279    0.377508           895445         0.569779
# C              451840    0.287510          1347285         0.857289
# D              224280    0.142711          1571565         1.000000
#
#
#
#
# **** Frequency Table for n_d_sub_grade ****
#
#                Abs. Freq.  Rel. Freq.  Cum. Abs. Freq.  Cum. Rel. Freq.
# n_d_sub_grade
# OTHER             1571565         1.0          1571565              1.0
#
#
#
#
# **** Frequency Table for n_d_emp_length ****
#
#                 Abs. Freq.  Rel. Freq.  Cum. Abs. Freq.  Cum. Rel. Freq.
# n_d_emp_length
# 10+ years           520397    0.331133           520397         0.331133
# OTHER              1051168    0.668867          1571565         1.000000
#
#
#
#
# **** Frequency Table for n_d_home_ownership ****
#
#                     Abs. Freq.  Rel. Freq.  Cum. Abs. Freq.  Cum. Rel. Freq.
# n_d_home_ownership
# MORTGAGE                773927    0.492456           773927         0.492456
# OWN                     175927    0.111944           949854         0.604400
# RENT                    621711    0.395600          1571565         1.000000
#
#
#
#
# **** Frequency Table for n_d_purpose ****
#
#                     Abs. Freq.  Rel. Freq.  Cum. Abs. Freq.  Cum. Rel. Freq.
# n_d_purpose
# OTHER                   322930    0.205483           322930         0.205483
# credit_card             360020    0.229084           682950         0.434567
# debt_consolidation      888615    0.565433          1571565         1.000000
#
#
#
#
# **** Frequency Table for n_d_addr_state ****
#
#                 Abs. Freq.  Rel. Freq.  Cum. Abs. Freq.  Cum. Rel. Freq.
# n_d_addr_state
# CA                  218805    0.139227           218805         0.139227
# OTHER              1352760    0.860773          1571565         1.000000
#
#
#
#
# **** Frequency Table for n_d_application_type ****
#
#                       Abs. Freq.  Rel. Freq.  Cum. Abs. Freq.  Cum. Rel. Freq.
# n_d_application_type
# Individual               1571565         1.0          1571565              1.0
#
#
#
#
# **** Frequency Table for n_d_disbursement_method ****
#
#                          Abs. Freq.  Rel. Freq.  Cum. Abs. Freq.  \
# n_d_disbursement_method
# Cash                        1571565         1.0          1571565
#
#                          Cum. Rel. Freq.
# n_d_disbursement_method
# Cash                                 1.0

# %%
unarias = [v[2:] for v in varn if train[v].nunique()==1]
unarias
# Out:
# ['d_sub_grade', 'd_application_type', 'd_disbursement_method']

# %%
vard = [v for v in vard if v not in unarias]
train.drop(unarias,axis=1,inplace=True)
dn.fit(train[vard])

# %%
train.drop(varn,axis=1,inplace=True)
varn = [f'n_{v}' for v in vard]
train[varn] = dn.transform(train[vard])

# %%
frequency_table(train,varn)
# Out:
# **** Frequency Table for n_d_grade ****
#
#            Abs. Freq.  Rel. Freq.  Cum. Abs. Freq.  Cum. Rel. Freq.
# n_d_grade
# A              302166    0.192271           302166         0.192271
# B              593279    0.377508           895445         0.569779
# C              451840    0.287510          1347285         0.857289
# D              224280    0.142711          1571565         1.000000
#
#
#
#
# **** Frequency Table for n_d_emp_length ****
#
#                 Abs. Freq.  Rel. Freq.  Cum. Abs. Freq.  Cum. Rel. Freq.
# n_d_emp_length
# 10+ years           520397    0.331133           520397         0.331133
# OTHER              1051168    0.668867          1571565         1.000000
#
#
#
#
# **** Frequency Table for n_d_home_ownership ****
#
#                     Abs. Freq.  Rel. Freq.  Cum. Abs. Freq.  Cum. Rel. Freq.
# n_d_home_ownership
# MORTGAGE                773927    0.492456           773927         0.492456
# OWN                     175927    0.111944           949854         0.604400
# RENT                    621711    0.395600          1571565         1.000000
#
#
#
#
# **** Frequency Table for n_d_purpose ****
#
#                     Abs. Freq.  Rel. Freq.  Cum. Abs. Freq.  Cum. Rel. Freq.
# n_d_purpose
# OTHER                   322930    0.205483           322930         0.205483
# credit_card             360020    0.229084           682950         0.434567
# debt_consolidation      888615    0.565433          1571565         1.000000
#
#
#
#
# **** Frequency Table for n_d_addr_state ****
#
#                 Abs. Freq.  Rel. Freq.  Cum. Abs. Freq.  Cum. Rel. Freq.
# n_d_addr_state
# CA                  218805    0.139227           218805         0.139227
# OTHER              1352760    0.860773          1571565         1.000000

# %% [markdown]
# ### Matriz de predictoras $\mathcal{X}$

# %%
oh = OneHotEncoder(drop='if_binary',sparse_output=False)
oh.fit(train[varn])
varoh = list(oh.get_feature_names_out())
varoh
# Out:
# ['n_d_grade_A',
#  'n_d_grade_B',
#  'n_d_grade_C',
#  'n_d_grade_D',
#  'n_d_emp_length_OTHER',
#  'n_d_home_ownership_MORTGAGE',
#  'n_d_home_ownership_OWN',
#  'n_d_home_ownership_RENT',
#  'n_d_purpose_OTHER',
#  'n_d_purpose_credit_card',
#  'n_d_purpose_debt_consolidation',
#  'n_d_addr_state_OTHER']

# %%
X = train[mc].copy()
X[varoh] = oh.transform(train[varn])
X.head()
im = SimpleImputer(strategy='median')
im.fit(X)
X = pd.DataFrame(im.transform(X),columns=X.columns)

# %% [markdown]
# ### Vector respuesta $\vec{y}$

# %%
y = train[vart[0]]
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    1
# Name: target, dtype: int64

# %% [markdown]
# ## Aprendizaje

# %%
var = mc+varoh

# %% [markdown]
# ### Predictoras más fuertes

# %%
sk = SelectKBest(k=len(var))
sk.fit(X,y)
# Out:
# SelectKBest(k=28)

# %%
pd.Series(dict(zip(var,sk.scores_))).sort_values(ascending=False).plot(kind='bar')
# Out:
# <Axes: >

# %%
k = 10
sk = SelectKBest(k=k)
sk.fit(X,y)
# Out:
# SelectKBest()

# %%
best = [v for v,s in zip(var,sk.get_support()) if s]
best
# Out:
# ['c_tot_cur_bal',
#  'c_mo_sin_rcnt_rev_tl_op',
#  'c_total_bc_limit',
#  'c_bc_util',
#  'c_mths_since_recent_inq',
#  'c_fico_range_high',
#  'n_d_grade_A',
#  'n_d_grade_D',
#  'n_d_home_ownership_MORTGAGE',
#  'n_d_home_ownership_RENT']

# %%
X = train[mc+vard].copy()
X[varn] = dn.transform(X[vard])
X[varoh] = oh.transform(train[varn])
X.head()
im = SimpleImputer(strategy='median')
im.fit(X[best])
X = pd.DataFrame(im.transform(X[best]),columns=best)

# %% [markdown]
# ### Híper-parametrización

# %%
hparam_grid = {
    'criterion': ['gini', 'entropy'],
    'splitter': ['best', 'random'],
    'max_depth': range(2,6),
    'min_samples_split': np.arange(0.05,0.1,0.01),
    'min_samples_leaf': np.arange(0.05,0.1,0.01),
    'min_weight_fraction_leaf': np.arange(0.05,0.1,0.01),
    'max_features': ['auto', 'sqrt', 'log2'],
    'max_leaf_nodes': range(2,11)
}

# %%
reduce(lambda x,y: x*y, map(len,hparam_grid.values()))
# Out:
# 54000

# %%
dt = DecisionTreeClassifier()

# %%
grid = RandomizedSearchCV(
    estimator=dt,
    param_distributions=hparam_grid,
    scoring='roc_auc',
    n_jobs=-1,
    cv=5,
    n_iter=100,
    verbose=True,
)

# %%
grid.fit(X,y)
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# /Users/gus/Library/Mobile Documents/com~apple~CloudDocs/trabajo_gus/anahuac/didactic-octo-telegram/.venv/lib/python3.13/site-packages/sklearn/model_selection/_validation.py:516: FitFailedWarning:
# 175 fits failed out of a total of 500.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 120 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/gus/Library/Mobile Documents/com~apple~CloudDocs/trabajo_gus/anahuac/didactic-octo-telegram/.venv/lib/python3.13/site-packages/sklearn/model_selection/_validation.py", line 859, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#     ~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/gus/Library/Mobile Documents/com~apple~CloudDocs/trabajo_gus/anahuac/didactic-octo-telegram/.venv/lib/python3.13/site-packages/sklearn/base.py", line 1358, in wrapper
#     estimator._validate_params()
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "/Users/gus/Library/Mobile Documents/com~apple~CloudDocs/trabajo_gus/anahuac/didactic-octo-telegram/.venv/lib/python3.13/site-packages/sklearn/base.py", line 471, in _validate_params
#     validate_parameter_constraints(
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^
#         self._parameter_constraints,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         self.get_params(deep=False),
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         caller_name=self.__class__.__name__,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "/Users/gus/Library/Mobile Documents/com~apple~CloudDocs/trabajo_gus/anahuac/didactic-octo-telegram/.venv/lib/python3.13/site-packages/sklearn/utils/_param_validation.py", line 98, in validate_parameter_constraints
#     raise InvalidParameterError(
#     ...<2 lines>...
#     )
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of DecisionTreeClassifier must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'log2'} or None. Got 'auto' instead.
#
# --------------------------------------------------------------------------------
# 55 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/gus/Library/Mobile Documents/com~apple~CloudDocs/trabajo_gus/anahuac/didactic-octo-telegram/.venv/lib/python3.13/site-packages/sklearn/model_selection/_validation.py", line 859, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#     ~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/gus/Library/Mobile Documents/com~apple~CloudDocs/trabajo_gus/anahuac/didactic-octo-telegram/.venv/lib/python3.13/site-packages/sklearn/base.py", line 1358, in wrapper
#     estimator._validate_params()
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "/Users/gus/Library/Mobile Documents/com~apple~CloudDocs/trabajo_gus/anahuac/didactic-octo-telegram/.venv/lib/python3.13/site-packages/sklearn/base.py", line 471, in _validate_params
#     validate_parameter_constraints(
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^
#         self._parameter_constraints,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         self.get_params(deep=False),
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         caller_name=self.__class__.__name__,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "/Users/gus/Library/Mobile Documents/com~apple~CloudDocs/trabajo_gus/anahuac/didactic-octo-telegram/.venv/lib/python3.13/site-packages/sklearn/utils/_param_validation.py", line 98, in validate_parameter_constraints
#     raise InvalidParameterError(
#     ...<2 lines>...
#     )
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of DecisionTreeClassifier must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'log2', 'sqrt'} or None. Got 'auto' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /Users/gus/Library/Mobile Documents/com~apple~CloudDocs/trabajo_gus/anahuac/didactic-octo-telegram/.venv/lib/python3.13/site-packages/sklearn/model_selection/_search.py:1135: UserWarning: One or more of the test scores are non-finite: [0.59559968 0.60807489        nan 0.5941145  0.57919744 0.62274601
#  0.60516913 0.62259398 0.617242   0.62026403        nan 0.58200695
#  0.62200847        nan 0.6077766  0.56285647        nan 0.59468647
#  0.62465791 0.54862414        nan        nan        nan 0.61945206
#         nan 0.60079686        nan 0.58981197 0.56016546        nan
#         nan 0.61461268 0.57897614 0.61068193 0.57842854 0.58865918
#  0.60062729 0.61646422 0.62414609 0.56470294        nan 0.56236484
#  0.62534442 0.56117868        nan        nan        nan 0.58563684
#  0.55987503        nan        nan 0.60560003 0.60107    0.57415037
#  0.61710438        nan        nan        nan 0.59966878 0.60769956
#         nan 0.59562811 0.60418606        nan 0.61688261 0.59812266
#  0.56832326 0.58971648        nan        nan 0.60797207 0.62248783
#  0.56205215 0.579441   0.61355484        nan 0.61545151        nan
#         nan        nan        nan 0.596742          nan 0.59871811
#  0.5884693  0.57366637 0.59297619        nan 0.60019826        nan
#         nan 0.59964957        nan 0.57865147        nan 0.60930939
#  0.6202925  0.59747199 0.62190456 0.57208333]
#   warnings.warn(
# RandomizedSearchCV(cv=5,
#                    estimator=DecisionTreeClassifier(criterion='entropy',
#                                                     max_depth=5,
#                                                     max_features='log2',
#                                                     max_leaf_nodes=9,
#                                                     min_samples_leaf=np.float64(0.08000000000000002),
#                                                     min_samples_split=np.float64(0.08000000000000002),
#                                                     min_weight_fraction_leaf=np.float64(0.060000000000000005)),
#                    n_iter=100, n_jobs=-1,
#                    param_distributions={'criterion': ['gini', 'entropy'],
#                                         'max_depth': range(2, 6),
#                                         'max_features': ['auto', 'sqrt',
#                                                          'log2'],
#                                         'max_leaf_nodes': range(2, 11),
#                                         'min_samples_leaf': array([0.05, 0.06, 0.07, 0.08, 0.09]),
#                                         'min_samples_split': array([0.05, 0.06, 0.07, 0.08, 0.09]),
#                                         'min_weight_fraction_leaf': array([0.05, 0.06, 0.07, 0.08, 0.09]),
#                                         'splitter': ['best', 'random']},
#                    scoring='roc_auc', verbose=True)

# %%
grid.best_score_
# Out:
# np.float64(0.6253444176288071)

# %%
dt = grid.best_estimator_
dt
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=5, max_features='sqrt',
#                        max_leaf_nodes=7,
#                        min_samples_leaf=np.float64(0.060000000000000005),
#                        min_samples_split=np.float64(0.07),
#                        min_weight_fraction_leaf=np.float64(0.060000000000000005))

# %% [markdown]
# ### Aprendizaje final $\vec{y} = f (\mathcal{X};\theta)$  (Ahora si vamos a aprender el modelo)

# %%
dt.fit(X,y)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=5, max_features='sqrt',
#                        max_leaf_nodes=7,
#                        min_samples_leaf=np.float64(0.060000000000000005),
#                        min_samples_split=np.float64(0.07),
#                        min_weight_fraction_leaf=np.float64(0.060000000000000005))

# %% [markdown]
# ## Generalización del modelo (qué tan bien se comporta en datos que nunca vió, es importante aplicar TODAS las transfromaciones previas)

# %%
Xv = valid[mc+vard].copy()
Xv[varn] = dn.transform(Xv[vard])
Xv[varoh] = oh.transform(Xv[varn])
Xv = pd.DataFrame(im.transform(Xv[best]),columns=best)

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

# Training ROC and AUC
y_train_proba = dt.predict_proba(X)[:, 1]
fpr_train, tpr_train, _ = roc_curve(y, y_train_proba)
auc_train = auc(fpr_train, tpr_train)

# Validation ROC and AUC
y_valid = valid[vart[0]]
y_valid_proba = dt.predict_proba(Xv)[:, 1]
fpr_valid, tpr_valid, _ = roc_curve(y_valid, y_valid_proba)
auc_valid = auc(fpr_valid, tpr_valid)

plt.figure(figsize=(9, 7))
plt.plot(fpr_train, tpr_train, color='#1f77b4', lw=3, label=f'Train ROC (AUC = {auc_train:.3f})')
plt.plot(fpr_valid, tpr_valid, color='#ff7f0e', lw=3, label=f'Validation ROC (AUC = {auc_valid:.3f})')
plt.plot([0, 1], [0, 1], color='gray', lw=2, linestyle='--', label='Random Guess')

plt.title('ROC Curve for Decision Tree', fontsize=20, fontweight='bold', color='#333333', pad=20)
plt.xlabel('False Positive Rate', fontsize=16, fontweight='bold')
plt.ylabel('True Positive Rate', fontsize=16, fontweight='bold')
plt.legend(fontsize=14, loc='lower right', frameon=True, fancybox=True, shadow=True)
plt.grid(True, linestyle=':', linewidth=1.2, alpha=0.7)
plt.gca().set_facecolor('#f7f7f7')
plt.tick_params(axis='both', which='major', labelsize=13)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(24, 12))
plot_tree(
    dt,
    feature_names=best,
    class_names=['Good', 'Bad'],
    filled=True,
    rounded=True,
    proportion=True,
    impurity=False,
    precision=3,
    fontsize=12,
    label='all'
)
plt.title("Final Decision Tree (Node Probabilities, Color by Class)", fontsize=20, fontweight='bold', pad=20)
plt.show()

# %% [markdown]
# ## Uso del modelo

# %%
train_node_ids = dt.apply(X)
valid_node_ids = dt.apply(Xv)

# Build DataFrames for train and valid
df_train_nodes = pd.DataFrame({
    'target': y.values,
    'node': train_node_ids,
    'sample': 'train'
})

df_valid_nodes = pd.DataFrame({
    'target': y_valid.values,
    'node': valid_node_ids,
    'sample': 'valid'
})

# Concatenate into a single DataFrame
df_nodes = pd.concat([df_train_nodes, df_valid_nodes], ignore_index=True)

# Show the first few rows
df_nodes.head()
# Out:
#    target  node sample
# 0       0     2  train
# 1       0     7  train
# 2       0     7  train
# 3       0     4  train
# 4       1    11  train

# %%
df_nodes.assign(n=1).groupby(list(df_nodes.columns)).count().to_clipboard()
